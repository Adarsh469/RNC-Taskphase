# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /home/goosbo/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# # Parsing the train.csv file

# %%
traindata = pd.read_csv('Train.csv')
traindata = traindata.drop(['Unnamed: 0','Name'],axis=1)
traindata = pd.get_dummies(traindata,columns=['Location','Fuel_Type','Transmission','Owner_Type'],drop_first=True)
traindata = traindata.dropna()
traindata.Mileage = traindata.Mileage.str.replace(' kmpl','').astype(float)
traindata.Engine = traindata.Engine.str.replace(' CC','').astype(float)
traindata = traindata[traindata.Power != 'null bhp']
traindata.Power = traindata.Power.str.replace(' bhp','').astype(float)

traindata
# Out:
#       Year  Kilometers_Driven  Mileage  Engine   Power  Seats  Price  \
# 0     2017              16500    23.84  1199.0   84.00    5.0   5.00
# 1     2017              47357    18.49  1493.0  100.00    7.0   8.37
# 2     2014              35000    15.00  1598.0  103.52    5.0   4.50
# 3     2007             200000    17.20  1396.0   53.50    5.0   0.85
# 4     2013              64000    21.02  1248.0   88.76    5.0   2.65
# ...    ...                ...      ...     ...     ...    ...    ...
# 3745  2009             150000    11.00  2993.0  235.00    5.0  18.75
# 3746  2012              85000    11.79  2179.0  120.00    7.0   6.25
# 3747  2007              55100    18.90   998.0   67.10    5.0   1.45
# 3748  2014              77500    20.45  1461.0   83.80    5.0   6.60
# 3749  2012              40000    18.90   998.0   67.10    5.0   2.35
#
#       Location_Bangalore  Location_Chennai  Location_Coimbatore  ...  \
# 0                  False             False                False  ...
# 1                  False             False                False  ...
# 2                  False             False                False  ...
# 3                  False             False                False  ...
# 4                  False             False                False  ...
# ...                  ...               ...                  ...  ...
# 3745               False              True                False  ...
# 3746               False             False                False  ...
# 3747               False             False                False  ...
# 3748               False             False                False  ...
# 3749               False             False                False  ...
#
#       Location_Kochi  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0              False             False            False          False
# 1               True             False            False          False
# 2              False             False             True          False
# 3              False             False            False          False
# 4              False             False             True          False
# ...              ...               ...              ...            ...
# 3745           False             False            False          False
# 3746           False             False            False          False
# 3747           False             False            False          False
# 3748           False             False            False          False
# 3749           False              True            False          False
#
#       Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual  \
# 0                  False              True                 True
# 1                  False             False                False
# 2                  False              True                 True
# 3                  False             False                 True
# 4                  False             False                 True
# ...                  ...               ...                  ...
# 3745               False             False                False
# 3746               False             False                False
# 3747               False              True                 True
# 3748               False             False                 True
# 3749               False              True                 True
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False               True             False
# 4                         False               True             False
# ...                         ...                ...               ...
# 3745                      False              False             False
# 3746                      False              False             False
# 3747                      False              False             False
# 3748                      False              False             False
# 3749                      False              False             False
#
# [3649 rows x 23 columns]

# %% [markdown]
# # Z-Score Standardization of data

# %%
notHotEncoded = traindata.select_dtypes(include=['int64','float64']).columns
notHotEncoded = notHotEncoded.drop('Price')
for i in notHotEncoded:
    traindata[i] = (traindata[i] - traindata[i].mean())/traindata[i].std()
    
traindata
# Out:
#           Year  Kilometers_Driven   Mileage    Engine     Power     Seats  \
# 0     1.127269          -1.020251  1.316366 -0.711259 -0.546072 -0.351374
# 1     1.127269          -0.255071  0.068488 -0.223363 -0.251070  2.121461
# 2     0.176632          -0.561495 -0.745549 -0.049114 -0.186170 -0.351374
# 3    -2.041520           3.530111 -0.232403 -0.384335 -1.108418 -0.351374
# 4    -0.140247           0.157636  0.658606 -0.629943 -0.458309 -0.351374
# ...        ...                ...       ...       ...       ...       ...
# 3745 -1.407762           2.290231 -1.678542  2.265903  2.238006 -0.351374
# 3746 -0.457125           0.678385 -1.494276  0.915061  0.117682  2.121461
# 3747 -2.041520          -0.063063  0.164119 -1.044820 -0.857667 -0.351374
# 3748  0.176632           0.492403  0.525654 -0.276467 -0.549759 -0.351374
# 3749 -0.457125          -0.437507  0.164119 -1.044820 -0.857667 -0.351374
#
#       Price  Location_Bangalore  Location_Chennai  Location_Coimbatore  ...  \
# 0      5.00               False             False                False  ...
# 1      8.37               False             False                False  ...
# 2      4.50               False             False                False  ...
# 3      0.85               False             False                False  ...
# 4      2.65               False             False                False  ...
# ...     ...                 ...               ...                  ...  ...
# 3745  18.75               False              True                False  ...
# 3746   6.25               False             False                False  ...
# 3747   1.45               False             False                False  ...
# 3748   6.60               False             False                False  ...
# 3749   2.35               False             False                False  ...
#
#       Location_Kochi  Location_Kolkata  Location_Mumbai  Location_Pune  \
# 0              False             False            False          False
# 1               True             False            False          False
# 2              False             False             True          False
# 3              False             False            False          False
# 4              False             False             True          False
# ...              ...               ...              ...            ...
# 3745           False             False            False          False
# 3746           False             False            False          False
# 3747           False             False            False          False
# 3748           False             False            False          False
# 3749           False              True            False          False
#
#       Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual  \
# 0                  False              True                 True
# 1                  False             False                False
# 2                  False              True                 True
# 3                  False             False                 True
# 4                  False             False                 True
# ...                  ...               ...                  ...
# 3745               False             False                False
# 3746               False             False                False
# 3747               False              True                 True
# 3748               False             False                 True
# 3749               False              True                 True
#
#       Owner_Type_Fourth & Above  Owner_Type_Second  Owner_Type_Third
# 0                         False              False             False
# 1                         False              False             False
# 2                         False              False             False
# 3                         False               True             False
# 4                         False               True             False
# ...                         ...                ...               ...
# 3745                      False              False             False
# 3746                      False              False             False
# 3747                      False              False             False
# 3748                      False              False             False
# 3749                      False              False             False
#
# [3649 rows x 23 columns]

# %% [markdown]
# # Checking for the correlation of features to find redundant features and features with low correlation

# %%
traincorr = traindata.select_dtypes(include=['float64', 'int64']).corr()
#traincorr = traincorr.drop(['Price'] )
#traincorr = traincorr.drop(['Price'] , axis  = 1 )
sns.heatmap(traincorr)
#Seats and Kilometers_Driven has a very low correlation with price so I dropped them
#Since Engine has high correlation with Power, I dropped it because it is a redundant feature
traindata = traindata.drop(['Seats','Kilometers_Driven','Engine'],axis=1)
traincorr
# Out:
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.423923  0.293728 -0.074937  0.018804
# Kilometers_Driven -0.423923           1.000000 -0.132611  0.153966  0.005265
# Mileage            0.293728          -0.132611  1.000000 -0.631421 -0.531372
# Engine            -0.074937           0.153966 -0.631421  1.000000  0.864727
# Power              0.018804           0.005265 -0.531372  0.864727  1.000000
# Seats              0.005696           0.193156 -0.317068  0.387373  0.091839
# Price              0.306133          -0.156744 -0.334169  0.649705  0.761909
#
#                       Seats     Price
# Year               0.005696  0.306133
# Kilometers_Driven  0.193156 -0.156744
# Mileage           -0.317068 -0.334169
# Engine             0.387373  0.649705
# Power              0.091839  0.761909
# Seats              1.000000  0.051917
# Price              0.051917  1.000000

# %% [markdown]
# # Parsing the Test.csv file and applying standardization

# %%
testdata = pd.read_csv('Test.csv')
testdata = testdata.drop(['Unnamed: 0','Name'],axis=1)
testdata = pd.get_dummies(testdata,columns=['Location','Fuel_Type','Transmission','Owner_Type'],drop_first=True)
testdata = testdata.dropna()
testdata.Mileage = testdata.Mileage.str.replace(' kmpl','').astype(float)
testdata.Engine = testdata.Engine.str.replace(' CC','').astype(float)
testdata = testdata[testdata.Power != 'null bhp']
testdata.Power = testdata.Power.str.replace(' bhp','').astype(float)
testnotHotEncoded = testdata.select_dtypes(include=['int64','float64']).columns
testnotHotEncoded = testnotHotEncoded.drop('Price')
for i in notHotEncoded:
    testdata[i] = (testdata[i] - testdata[i].mean())/testdata[i].std()
testdata = testdata.drop(['Seats','Kilometers_Driven','Engine'],axis=1)
testdata
# Out:
#           Year   Mileage     Power  Price  Location_Bangalore  \
# 0    -0.166278  1.236734 -0.801440   6.95               False
# 1    -0.483790 -0.287738 -0.704491   2.90               False
# 2     1.103767  0.102244 -0.645925   6.28               False
# 3    -0.801301 -1.103152  1.988335  13.80               False
# 4    -0.166278  0.518223 -0.704491   2.75               False
# ...        ...       ...       ...    ...                 ...
# 1245 -0.166278  1.071287  0.231370   6.80               False
# 1246 -2.706370 -0.323190 -0.623370   0.80               False
# 1247  1.103767 -0.226286 -0.217764   8.27               False
# 1248 -0.483790  0.215693  0.233744   6.00               False
# 1249  1.738790  0.764030 -0.621391   9.51               False
#
#       Location_Chennai  Location_Coimbatore  Location_Delhi  \
# 0                False                False           False
# 1                False                False            True
# 2                False                False           False
# 3                False                False           False
# 4                False                False            True
# ...                ...                  ...             ...
# 1245             False                False            True
# 1246             False                False           False
# 1247             False                 True           False
# 1248             False                False           False
# 1249             False                False           False
#
#       Location_Hyderabad  Location_Jaipur  Location_Kochi  Location_Kolkata  \
# 0                   True            False           False             False
# 1                  False            False           False             False
# 2                  False            False            True             False
# 3                  False            False           False             False
# 4                  False            False           False             False
# ...                  ...              ...             ...               ...
# 1245               False            False           False             False
# 1246               False            False           False             False
# 1247               False            False           False             False
# 1248               False            False           False             False
# 1249               False            False            True             False
#
#       Location_Mumbai  Location_Pune  Fuel_Type_Electric  Fuel_Type_Petrol  \
# 0               False          False               False             False
# 1               False          False               False              True
# 2               False          False               False              True
# 3               False           True               False             False
# 4               False          False               False              True
# ...               ...            ...                 ...               ...
# 1245            False          False               False             False
# 1246            False           True               False              True
# 1247            False          False               False              True
# 1248            False           True               False             False
# 1249            False          False               False              True
#
#       Transmission_Manual  Owner_Type_Fourth & Above  Owner_Type_Second  \
# 0                    True                      False              False
# 1                   False                      False              False
# 2                    True                      False              False
# 3                   False                      False              False
# 4                    True                      False              False
# ...                   ...                        ...                ...
# 1245                False                      False              False
# 1246                 True                      False              False
# 1247                False                      False              False
# 1248                False                      False              False
# 1249                False                      False              False
#
#       Owner_Type_Third
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 1245             False
# 1246              True
# 1247             False
# 1248             False
# 1249             False
#
# [1224 rows x 20 columns]

# %%
Xtrain = traindata.drop('Price',axis=1).to_numpy()
Ytrain = traindata.Price.to_numpy()

Xtest = testdata.drop('Price',axis=1).to_numpy()
Ytest = testdata.Price.to_numpy()

# %%
#a is regularization constant

def cost(x,y,w,b,a):
    m,n = x.shape
    f = (np.dot(x,w)+b)
    cost = 0.5 *( np.mean((f-y)**2)+a*np.sum(w**2)/m)
    return cost

def gradient(x,y,w,b,a):
    m,n = x.shape
    dwj = np.zeros(n)
    dbj = 0
    error = (x.dot(w)+b)-y
    dbj += np.sum(error)
    dwj = np.dot(x.T,error)
    dwj += a*w
    return dbj/m,dwj/m

# %% [markdown]
# # Implementing Gradient Descent

# %%
def gradientdescent(x,y,winit,binit,alpha,gradientfunc,iterations,a=0):
    costs = []
    w = winit
    b = binit
    for i in range(iterations):
        dbj,dwj=gradientfunc(x,y,w,b,a)
        #alpha is the learning rate
        w -= alpha*dwj
        b -= alpha*dbj
        c = cost(x,y,w,b,a)
        costs.append(c)

    return w,b,costs

# %%
winit = np.zeros_like(Xtrain[0])
binit = 0
costs = []
w,b,costs = gradientdescent(Xtrain,Ytrain,winit,binit,0.01,gradient,2000,10)
print(f"w = {w} b = {b}")
# Out:
# w = [3.284890246152295 -0.5181165524270558 7.536989019313938
#  1.8957864557254438 1.2137996205856303 2.431311305661921
#  -0.2708310468092539 2.623728443696934 1.008153561671938
#  0.6720034091589472 -0.40123278730488665 -0.33429025829027004
#  0.7701555293414805 0.0 -1.5113564576487535 -1.6935213035837355
#  0.012993801308428182 0.027800380919435857 0.2423058636304058] b = 10.505008116320242

# %%
def predictedvalues(xt,w,b):
    m = xt.shape[0]
    ypredicted = np.zeros(m)
    for i in range(m):
        ypredicted[i] = np.dot(xt[i],w)+b

        #Since our y values are never negative, I put a minimum cap of zero on the predicted cost
        if ypredicted[i] < 0:
            ypredicted[i] = 0
    return ypredicted

yp = predictedvalues(Xtest,w,b)
meansquare = ((yp-Ytest)**2).mean()
rootmeansquare = np.sqrt(meansquare)
rootmeansquare

print(f"Mean Square Error: {meansquare}\nRoot Mean Square Error: {rootmeansquare}")
# Out:
# Mean Square Error: 35.30746457949593
# Root Mean Square Error: 5.942008463431867

# %%
def rsquared(yt,ypredicted):
    rsumsq = np.sum((yt-ypredicted)**2)
    tsumsq = np.sum((yt-yt.mean())**2)
    return 1-rsumsq/tsumsq
print(f"R-Squared: {rsquared(Ytest,yp)}")
print(f"Training data R-Squared: {rsquared(Ytrain,predictedvalues(Xtrain,w,b))}")
# Since there is no drastic difference in training data r-squared value and test data r-squared value, the model doesn't have a lot of overfitting
# Out:
# R-Squared: 0.7171021324301678
# Training data R-Squared: 0.7148797891052399

# %%
plt.scatter(Ytest,yp,color='blue',alpha=0.55)
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.title('predicted vs test costs')
plt.show()

# %%
plt.plot(range(len(costs)),costs,color='red')
plt.ylabel('costs')
plt.xlabel('epochs')
plt.title('Cost vs Epoch')
plt.show()
